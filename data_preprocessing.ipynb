# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# 파일 경로
csv_files = [
    "/content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv",
    "/content/drive/MyDrive/Github/csv_files/blues_songs.csv",
    "/content/drive/MyDrive/Github/csv_files/dance_songs(csv_googleSheet).csv",
    "/content/drive/MyDrive/Github/csv_files/indept_songs.csv",
    "/content/drive/MyDrive/Github/csv_files/r&b_songs.csv",
    "/content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv",
    "/content/drive/MyDrive/Github/csv_files/rockmet_songs.csv",
    "/content/drive/MyDrive/Github/csv_files/trot_songs.csv"
]

# %%
# 각 파일에서 songid와 title을 추출
song_info = {file: pd.read_csv(file)[["SongID", "Title"]] for file in csv_files}

# 겹치는 songid와 해당 title 확인
overlap_info = {}

for file1, df1 in song_info.items():
    for file2, df2 in song_info.items():
        if file1 != file2:
            overlap_ids = set(df1["SongID"]).intersection(set(df2["SongID"]))
            if overlap_ids:
                for oid in overlap_ids:
                    title1 = df1[df1["SongID"] == oid]["Title"].values[0]
                    title2 = df2[df2["SongID"] == oid]["Title"].values[0]
                    overlap_info.setdefault(oid, {}).setdefault("files", []).extend([file1, file2])
                    overlap_info[oid].setdefault("titles", []).extend([title1, title2])

# 겹치는 songid, 해당 파일, 그리고 title 출력
for songid, data in overlap_info.items():
    print(f"SongID {songid} overlaps in files: {', '.join(data['files'])}")
    print(f"Titles: {', '.join(set(data['titles']))}")
# Out:
# SongID 35958308 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 그댄 행복에 살텐데 (2022)
# SongID 35252996 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 해요 (2022)
# SongID 36481254 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 찬란한 하루
# SongID 32224166 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 너의 번호를 누르고 (Prod. 영화처럼)
# SongID 31726704 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: yours
# SongID 33868791 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 고백
# SongID 30514366 overlaps in files: /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/ballad_songs(csv_googleSheet).csv
# Titles: 선물
# SongID 8124417 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 봄이 좋냐??
# SongID 31343875 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 첫사랑
# SongID 3894276 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 오래된 노래
# SongID 35553933 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 숲
# SongID 30260502 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 니가 보고싶은 밤
# SongID 30657307 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 썸 탈꺼야
# SongID 30657308 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: Blue
# SongID 31172510 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 헤어지던 밤
# SongID 30657311 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 나의 사춘기에게
# SongID 30163110 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 좋다고 말해
# SongID 30468654 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 남이 될 수 있을까
# SongID 34930368 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: Love story
# SongID 35361345 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 그라데이션
# SongID 34930369 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: Seoul
# SongID 34500931 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 그렇게 살아가는 것
# SongID 5466962 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 스토커
# SongID 31709523 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 나만, 봄
# SongID 31709524 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 별 보러 갈래?
# SongID 8194007 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 오늘
# SongID 34055256 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 김철수 씨 이야기
# SongID 3136472 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 사랑은 은하수 다방에서
# SongID 30611680 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 폰서트
# SongID 3472354 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: Little Star
# SongID 36371558 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: FRIEND THE END
# SongID 9620469 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 우주를 줄게
# SongID 36444534 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 부동의 첫사랑
# SongID 9620473 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 나만 안되는 연애
# SongID 32583036 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 나비와 고양이 (feat.백현 (BAEKHYUN))
# SongID 36590463 overlaps in files: /content/drive/MyDrive/Github/csv_files/blues_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/blues_songs.csv
# Titles: 여름날 (feat. 하현상)
# SongID 1698598 overlaps in files: /content/drive/MyDrive/Github/csv_files/dance_songs(csv_googleSheet).csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/dance_songs(csv_googleSheet).csv
# Titles: 거짓말
# SongID 33976677 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 찰나가 영원이 될 때 (The Eternal Moment)
# SongID 33978183 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 너를 생각해
# SongID 35953743 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 이제 우리 꿈에서만 만나
# SongID 35730708 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 우리 다투게 돼도 이것만 기억해 줄래 눈을 맞추고 서로가 서로의 손잡아 주며 낮은 목소리와 예쁜 말투로 상처 주지 않게 노력을 하고 ●
# SongID 31853557 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# SongID 34497207 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: Beige coat
# SongID 34817660 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/r&b_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 아무래도 난
# SongID 30773554 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: Downtown Baby
# SongID 32438894 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/raphiphop_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 어떻게 지내 (Prod. By VAN.C)
# SongID 3620493 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 안아줘
# SongID 32677268 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 낭만젊음사랑
# SongID 30086173 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 비행운
# SongID 33680289 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 잘 지내자, 우리
# SongID 33722789 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 널 떠올리는 중이야
# SongID 4848555 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마음을 가둬두네
# SongID 33043504 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 가을밤에 든 생각
# SongID 8036156 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: EVERYTHING
# SongID 420424 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 고백
# SongID 30383949 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: TOMBOY
# SongID 31093710 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 여행
# SongID 4451155 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 겨울을 걷는다
# SongID 34162394 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 조용히 완전히 영원히
# SongID 32476250 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 좋은 밤 좋은 꿈
# SongID 35060827 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 초록을거머쥔우리는
# SongID 8298724 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 뜨거운 여름밤은 가고 남은 건 볼품없지만
# SongID 2627301 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 고백
# SongID 8298729 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 꿈나라 별나라
# SongID 30444778 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 민들레 (single ver.)
# SongID 31666411 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 투게더!
# SongID 31666417 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 주저하는 연인들을 위해
# SongID 31666421 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 꿈과 책과 힘과 벽
# SongID 5385974 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 위잉위잉
# SongID 5506296 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 잘 지내자, 우리
# SongID 30444666 overlaps in files: /content/drive/MyDrive/Github/csv_files/indept_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/rockmet_songs.csv, /content/drive/MyDrive/Github/csv_files/indept_songs.csv
# Titles: 나랑 아니면

# %%
# 좋아요 수, 댓글 수 number type으로 변환
def clean_number(x):
    return int(x.replace(',', '').replace('개', '').strip())

# %%
# 파일 로드 및 초기 전처리
all_data = []
for file in csv_files:
    df = pd.read_csv(file)
    df['Likes'] = df['Likes'].apply(clean_number) # number type으로 변환
    df['CommentsCount'] = df['CommentsCount'].apply(clean_number) # number type으로 변환
    all_data.append(df)

# 모든 데이터프레임을 하나로 합치기
combined = pd.concat(all_data, ignore_index=True)

# %%
# 일단 모든 데이터 병합
combined
# Out:
#        SongID                     Title  Rank      Singer  \
# 0    36382580                  헤어지자 말해요     1         박재정
# 1    36616378               사막에서 꽃을 피우듯     2  우디 (Woody)
# 2    36595401  잘 지내자, 우리 (여름날 우리 X 로이킴)     3         로이킴
# 3    36518341                  나에게 그대만이     4          탑현
# 4     4446485                  너의 모든 순간     5         성시경
# ..        ...                       ...   ...         ...
# 795  36235896                     귀한 그대    96         손태진
# 796  33771624                사는 게 그런 거지    97         장민호
# 797  35810840                  풍악을 울려라!    98         장민호
# 798  34279648                       물망초    99         정동원
# 799  33453665                  내 마음속 최고   100         정동원
#
#                         Album   Likes ReleaseDate       Genre  CommentsCount  \
# 0                    1집 Alone  131651  2023.04.20         발라드           1295
# 1                 사막에서 꽃을 피우듯   54218  2023.07.14         발라드            752
# 2    잘 지내자, 우리 (여름날 우리 X 로이킴)   39371  2023.07.06         발라드            102
# 3                    나에게 그대만이   37388  2023.06.11         발라드             30
# 4         별에서 온 그대 OST Part.7  275709  2014.02.12  발라드, 국내드라마            489
# ..                        ...     ...         ...         ...            ...
# 795          불타는 트롯맨 결승전 신곡미션    2759  2023.03.01    성인가요/트로트            525
# 796                사는 게 그런 거지   10116  2021.08.08    성인가요/트로트            376
# 797                   ETERNAL    3607  2022.11.08    성인가요/트로트             36
# 798           그리움, 아낌없이 주는 나무    8309  2021.11.17    성인가요/트로트            128
# 799                  내 마음속 최고   11574  2021.05.05    성인가요/트로트            450
#
#                                                 Lyrics  \
# 0    헤어지자고 말하려 오늘너에게 가다가 우리 추억 생각해 봤어처음 본 네 얼굴마주친 눈...
# 1    아침에 눈 뜨는 게 너무 행복해졌어 널 사랑한다 말할 수 있어서 하늘에 감사해 ⠀네...
# 2    마음을 다 보여줬던 너와는 다르게지난 사랑에 겁을 잔뜩 먹은나는 뒷걸음질만 쳤다너는...
# 3    더 이상 나에게다른 사랑은 없다는 걸이제 나는 알아요나에게 사랑은항상 하나뿐이었다고...
# 4    이윽고 내가 한눈에너를 알아봤을 때모든 건 분명 달라지고 있었어내 세상은 널 알기 ...
# ..                                                 ...
# 795  나만의 그대는너무나도 아름다워그대를 보는 게 마치 내겐 꿈같아여전히 예뻐요변하지 않...
# 796  빛나는 꿈을 안고세상 위에 나섰건만늦은 퇴근 차창에 기대어피곤한 눈 감아본다오늘을 ...
# 797  풍악을 울려라 온 세상 떠들썩하게풍악을 울려라 내 님이 춤출 수 있게이 세상에서 제...
# 798  나를 잊지 말아요꿈에서라도 그대내 곁으로 올 순 없나요같은 하늘 아래에다시 볼 수 ...
# 799  누가 뭐라 해도 최고 최고내 마음속에 최고세상만사 다 제쳐두고어디든 부르면 달려갈 ...
#
#                                          AlbumImageURL           Composers  \
# 0    https://cdnimg.melon.co.kr/cm2/album/images/11...            박재정, 박현중
# 1    https://cdnimg.melon.co.kr/cm2/album/images/11...                 백마리
# 2    https://cdnimg.melon.co.kr/cm2/album/images/11...                 성용욱
# 3    https://cdnimg.melon.co.kr/cm2/album/images/11...                 유해준
# 4    https://cdnimg.melon.co.kr/cm/album/images/022...                 성시경
# ..                                                 ...                 ...
# 795  https://cdnimg.melon.co.kr/cm2/album/images/11...                 윤일상
# 796  https://cdnimg.melon.co.kr/cm2/album/images/10...                 조영수
# 797  https://cdnimg.melon.co.kr/cm2/album/images/11...                 이동철
# 798  https://cdnimg.melon.co.kr/cm2/album/images/10...                 조영수
# 799  https://cdnimg.melon.co.kr/cm2/album/images/10...  강진우, 이진호, 고진영, 유호석
#
#     Lyricists Arrangers
# 0         박재정       박현중
# 1         백마리       전주현
# 2    조은영, 성용욱  최상언, 김홍준
# 3         경재승  윤일진, 고선생
# 4         심현보       안준영
# ..        ...       ...
# 795       윤일상       윤일상
# 796       강은경   조영수, 한길
# 797       이용구       이동철
# 798       조영수       이유진
# 799       강진우  이진호, 고진영
#
# [800 rows x 14 columns]

# %%
# SongID를 기준으로 그룹화하고 필요한 처리 수행
def aggregate_rows(group):
    # 'Rank' 평균 처리
    rank_avg = group['Rank'].mean()

    # 'Likes'와 'CommentsCount'의 최대값 처리
    max_likes = group['Likes'].max()
    max_comments = group['CommentsCount'].max()

    # 첫번째 행을 기반으로 새로운 행을 만들되, 'Rank', 'Likes', 'CommentsCount'만 수정
    new_row = group.iloc[0].copy()
    new_row['Rank'] = rank_avg
    new_row['Likes'] = max_likes
    new_row['CommentsCount'] = max_comments

    return new_row

# %%
# SongID가 같을 경우 하나의 데이터로 처리
# Rank -> 같은 노래가 있는 경우 두 노래의 Rank값의 평균값으로 변환
# Likes, CommentsCount -> 같은 노래가 있는 경우, 좋아요 수와 댓글 수가 더 큰 값으로 값 할당
final_df = combined.groupby('SongID').apply(aggregate_rows).reset_index(drop=True)
final_df
# Out:
#        SongID                    Title  Rank             Singer  \
# 0        9573                  Endless  66.0                플라워
# 1       19807                    벌써 일년  42.0            브라운 아이즈
# 2       72689                   바람의 노래  72.0                조용필
# 3       73737                      발걸음  70.0            에메랄드 캐슬
# 4       89806               I Love You  64.0                포지션
# ..        ...                      ...   ...                ...
# 724  36780818          사랑이라 쓰고 이별이라 읽어  48.0                송하예
# 725  36781785             Good & Great  92.0            키 (KEY)
# 726  36784536  Right Now (Feat. Crush)  59.0        쿠기 (Coogie)
# 727  36784946   한 개도 몰라 (Feat. meenoi)  18.0  릴러말즈 (Leellamarz)
# 728  36802845             가까이 하고 싶은 그대  83.0           SOLE (쏠)
#
#                                  Album  Likes ReleaseDate     Genre  \
# 0                                  소품집  56940  2001.08.21      록/메탈
# 1                           Brown Eyes  74746  2001.06.07  R&B/Soul
# 2                              조용필 16집  18853  1997.05.01  성인가요/트로트
# 3                           Invitation  54396  1997.04.01      록/메탈
# 4                        I Love You...  62526  2000.12.28       발라드
# ..                                 ...    ...         ...       ...
# 724                    사랑이라 쓰고 이별이라 읽어   2852  2023.09.11       발라드
# 725  Good & Great - The 2nd Mini Album   9137  2023.09.11        댄스
# 726                          Right Now   3927  2023.09.12      랩/힙합
# 727                            한 개도 몰라   7927  2023.09.13      랩/힙합
# 728                     A Love Supreme    870  2023.09.18  R&B/Soul
#
#      CommentsCount                                             Lyrics  \
# 0               96  널 사랑해 눈을 감아도단 한 번만 볼 수 있다면하늘이여 내 모든 걸 가져가미련 없이...
# 1              229  처음이라 그래 며칠뒤엔 괜찮아져 그 생각만으로 벌써 일년이 너와 만든 기념일마다 슬...
# 2               93  살면서 듣게될까 언젠가는바람에 노래를세월가면 그때는 알게될까꽃이지는 이유를나를 떠난...
# 3               73  해질무렵 날 끌고간 발걸음눈떠보니 잊은줄 알았던 곳에아직도 너의 대한 미움이 남아 ...
# 4              177  I love you 사랑한다는 이 말 밖에는해줄 말이 없네요I love you 의미...
# ..             ...                                                ...
# 724             12  사랑이라 쓰고 이별이라 읽어바보같이 끝을 알고도 시작해새로운 결말이 있을거라고 생각...
# 725            202  I’m good I’m greatI work get paidThank god all...
# 726             41  찰나의 눈빛에 흔들려 내 맘시간이 없는데 벌써 late at night숨을 고른 채...
# 727             57  난 너의 마음을 한 개도 몰라두 개는 더 몰라세 번째에는 떠올랐지너가 우는 얼굴 말...
# 728              5  그대 눈빛만 보아도 나는 느낄 수 있어요나를 좋아하고 있다는 걸 처음부터 난 알 수...
#
#                                          AlbumImageURL  \
# 0    https://cdnimg.melon.co.kr/cm/album/images/000...
# 1    https://cdnimg.melon.co.kr/cm/album/images/000...
# 2    https://cdnimg.melon.co.kr/cm/album/images/000...
# 3    https://cdnimg.melon.co.kr/cm/album/images/000...
# 4    https://cdnimg.melon.co.kr/cm/album/images/000...
# ..                                                 ...
# 724  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 725  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 726  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 727  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 728  https://cdnimg.melon.co.kr/cm2/album/images/11...
#
#                                            Composers  \
# 0                                                플라워
# 1                                                 윤건
# 2                                                김정욱
# 3                                                김영석
# 4                                       Ozaki Yutaka
# ..                                               ...
# 724                                            TEAM8
# 725  Will Leong, James 'boy Matthews' Norton, Ferras
# 726                   GRAY (그레이), 쿠기 (Coogie), Crush
# 727            TOIL, 릴러말즈 (Leellamarz), meenoi (미노이)
# 728                                              유영선
#
#                            Lyricists             Arrangers
# 0                                하해룡                   NaN
# 1                                한경혜                    윤건
# 2                                김순곤        조용필, Tom Keane
# 3                        지우 (에메랄드캐슬)                   김영석
# 4                       Ozaki Yutaka                   NaN
# ..                               ...                   ...
# 724                            TEAM8                   유정현
# 725                           KENZIE            Will Leong
# 726               쿠기 (Coogie), Crush            GRAY (그레이)
# 727  릴러말즈 (Leellamarz), meenoi (미노이)                  TOIL
# 728                              이건우  HAEUN, SHINDRUM, 정용훈
#
# [729 rows x 14 columns]

# %%
final_df.to_csv("all_songs.csv", index=False, encoding="utf-8-sig")
